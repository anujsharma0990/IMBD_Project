# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Plot a graph to show the distribution of genre in the top 250 movies

# %%
# Load the movie data into a pandas DataFrame
df = pd.read_csv('movies.csv')

# Get the count of each genre in the top 250 movies
genre_counts = df['genre'].head(20).value_counts()

# Plot the graph
plt.figure(figsize=(8, 8))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Genres in Top 250 Movies')
plt.axis('equal')
# Out:
# (-1.0999990089481684, 1.0999999528070556, -1.1, 1.1)

# %% [markdown]
# # Find out which movie has the maximum number of votes and which genre it belongs to and its duration

# %%
df.columns
# Out:
# Index(['rank', 'movie_id', 'title', 'year', 'link', 'imbd_votes',
#        'imbd_rating', 'certificate', 'duration', 'genre', 'cast_id',
#        'cast_name', 'director_id', 'director_name', 'writer_id', 'writer_name',
#        'storyline', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content'],
#       dtype='object')

# %%
# Find the movie with the maximum number of votes
max_votes = df['imbd_votes'].max()

# Get the movie details for the movie with the maximum number of votes
movie_details = df[df.imbd_votes == max_votes][['title','genre','duration']]

movie_details
# Out:
#          title                   genre duration
# 184  Gone Girl  Drama,Mystery,Thriller   2h 29m

# %% [markdown]
# # Find out which movie has the minimum number of votes and which genre it belongs to and its duration

# %%
# Find the movie with the minimum number of votes
min_votes = df['imbd_votes'].min()

# Get the movie details for the movie with the minimum number of votes
movie_details = df[df['imbd_votes'] == min_votes][['title', 'genre', 'duration']]

movie_details
# Out:
#              title                    genre duration
# 143  Jurassic Park  Action,Adventure,Sci-Fi    2h 7m

# %% [markdown]
# # Find out movies of each genre which has maximum number of votes

# %%
# Finding the maximun number of votes in the dataset
max_votes = df['imbd_votes'].max()

# Filtering the DataFrame to retrieve the movies with the maximum number of votes
movies_max_votes = df[df['imbd_votes'] == max_votes]

# %%
gp = df.groupby(df["genre"]).agg({"imbd_votes":"max"})
gp
# Out:
#                          imbd_votes
# genre
# Action,Adventure            976,471
# Action,Adventure,Comedy      92,925
# Action,Adventure,Drama    1,895,357
# Action,Adventure,Fantasy    776,160
# Action,Adventure,Mystery    331,797
# ...                             ...
# Horror,Mystery,Thriller     679,428
# Horror,Sci-Fi               892,980
# Mystery,Romance,Thriller    407,006
# Mystery,Thriller            497,077
# Western                     333,809
#
# [104 rows x 1 columns]
